# %% [markdown]
# For my final project, I am analyzing movie data. In this notebook, I have collected a movie dataset from Kaggle. I imported the data from a csv file and made additional dataframes to help further my analysisThe dataset includes important features that will contribute to my final analysis. Some of these features include popularity, budget, runtime, genre, release date, revenue, directors, and cast. In this dataset, there are 10,866 movies which were released in the years 1966-2015.

# %%
import pandas as pd
import numpy as np
from scipy import stats
from matplotlib import pyplot as plt
import requests 
import base64
import urllib
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
tmbd_movie_data = pd.read_csv('tmdb_movies_data.csv')

# %%
tmbd_movie_data.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline  ...  \
# 0              The park is open.  ...
# 1             What a Lovely Day.  ...
# 2     One Choice Can Destroy You  ...
# 3  Every generation has a story.  ...
# 4            Vengeance Hits Home  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015       5292
# 4  Universal Pictures|Original Film|Media Rights ...     4/1/2015       2947
#
#    vote_average  release_year   budget_adj   revenue_adj
# 0           6.5          2015  137999939.3  1.392446e+09
# 1           7.1          2015  137999939.3  3.481613e+08
# 2           6.3          2015  101199955.5  2.716190e+08
# 3           7.5          2015  183999919.0  1.902723e+09
# 4           7.3          2015  174799923.1  1.385749e+09
#
# [5 rows x 21 columns]

# %%
tmbd_movie_data.keys()
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
all_movies_df = pd.DataFrame(tmbd_movie_data)

# %%
all_movies_df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline  ...  \
# 0              The park is open.  ...
# 1             What a Lovely Day.  ...
# 2     One Choice Can Destroy You  ...
# 3  Every generation has a story.  ...
# 4            Vengeance Hits Home  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015       5292
# 4  Universal Pictures|Original Film|Media Rights ...     4/1/2015       2947
#
#    vote_average  release_year   budget_adj   revenue_adj
# 0           6.5          2015  137999939.3  1.392446e+09
# 1           7.1          2015  137999939.3  3.481613e+08
# 2           6.3          2015  101199955.5  2.716190e+08
# 3           7.5          2015  183999919.0  1.902723e+09
# 4           7.3          2015  174799923.1  1.385749e+09
#
# [5 rows x 21 columns]

# %%
all_movies_df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
clean_all_movies_df = all_movies_df.drop(columns= ['id', 'imdb_id', 'homepage', 'tagline', 'overview', 'keywords'])

# %%
clean_all_movies_df.head()
# Out:
#    popularity     budget     revenue                original_title  \
# 0   32.985763  150000000  1513528810                Jurassic World
# 1   28.419936  150000000   378436354            Mad Max: Fury Road
# 2   13.112507  110000000   295238201                     Insurgent
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
# 1      120  Action|Adventure|Science Fiction|Thriller
# 2      119         Adventure|Science Fiction|Thriller
# 3      136   Action|Adventure|Science Fiction|Fantasy
# 4      137                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015        5292
# 4  Universal Pictures|Original Film|Media Rights ...     4/1/2015        2947
#
#    vote_average  release_year   budget_adj   revenue_adj
# 0           6.5          2015  137999939.3  1.392446e+09
# 1           7.1          2015  137999939.3  3.481613e+08
# 2           6.3          2015  101199955.5  2.716190e+08
# 3           7.5          2015  183999919.0  1.902723e+09
# 4           7.3          2015  174799923.1  1.385749e+09

# %% [markdown]
# In the dataframe above, I cleaned the dataframe by removing columns that are not necessary for my analysis. I kept the columns that I believe will help my analysis the best.

# %%
name_group = clean_all_movies_df.groupby("original_title").sum()

# %%
name_group.head()
# Out:
#                                     popularity   budget   revenue  \
# original_title
# $5 a Day                              0.298961        0         0
# $9.99                                 0.204302        0         0
# '71                                   1.220073        0   1625847
# (500) Days of Summer                  3.244139  7500000  60722734
# (T)Raumschiff Surprise - Periode 1    0.712887        0         0
#
#                                                                                  cast  \
# original_title
# $5 a Day                            Christopher Walken|Alessandro Nivola|Sharon St...
# $9.99                               Tom Budge|Josef Ber|Joel Edgerton|Leon Ford|Sa...
# '71                                 Jack O'Connell|Paul Anderson|Sean Harris|Sam R...
# (500) Days of Summer                Joseph Gordon-Levitt|Zooey Deschanel|ChloÃ« Gr...
# (T)Raumschiff Surprise - Periode 1  Michael Herbig|Rick Kavanian|Christian Tramitz...
#
#                                            director  runtime  \
# original_title
# $5 a Day                                 Nigel Cole       98
# $9.99                               Tatia Rosenthal       78
# '71                                    Yann Demange       99
# (500) Days of Summer                      Marc Webb       95
# (T)Raumschiff Surprise - Periode 1   Michael Herbig       87
#
#                                                        genres  \
# original_title
# $5 a Day                                         Drama|Comedy
# $9.99                                         Animation|Drama
# '71                                 Thriller|Action|Drama|War
# (500) Days of Summer                     Comedy|Drama|Romance
# (T)Raumschiff Surprise - Periode 1     Comedy|Science Fiction
#
#                                                                  production_companies  \
# original_title
# $5 a Day                                                              New Line Cinema
# $9.99                                             Australian Film Finance Corporation
# '71                                 Screen Yorkshire|British Film Institute (BFI)|...
# (500) Days of Summer                Fox Searchlight Pictures|Watermark|Dune Entert...
# (T)Raumschiff Surprise - Periode 1                                    herbX film GmbH
#
#                                    release_date  vote_count  vote_average  \
# original_title
# $5 a Day                               1/1/2008          12           5.4
# $9.99                                  9/4/2008          18           6.1
# '71                                  10/10/2014         274           6.6
# (500) Days of Summer                  7/17/2009        1778           7.3
# (T)Raumschiff Surprise - Periode 1    7/14/2004          80           6.3
#
#                                     release_year   budget_adj   revenue_adj
# original_title
# $5 a Day                                    2008        0.000  0.000000e+00
# $9.99                                       2008        0.000  0.000000e+00
# '71                                         2014        0.000  1.497553e+06
# (500) Days of Summer                        2009  7623003.256  6.171861e+07
# (T)Raumschiff Surprise - Periode 1          2004        0.000  0.000000e+00

# %% [markdown]
# The dataframe above shows grouping the data by Movie Title.

# %%
popular_sorted_df = name_group.sort_values(by ='popularity', ascending= False)

# %%
popular_sorted_df.head()
# Out:
#                          popularity     budget     revenue  \
# original_title
# Jurassic World            32.985763  150000000  1513528810
# Mad Max: Fury Road        28.419936  150000000   378436354
# Interstellar              24.949134  165000000   621752480
# Guardians of the Galaxy   14.311205  170000000   773312399
# Insurgent                 13.112507  110000000   295238201
#
#                                                                       cast  \
# original_title
# Jurassic World           Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# Mad Max: Fury Road       Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# Interstellar             Matthew McConaughey|Jessica Chastain|Anne Hath...
# Guardians of the Galaxy  Chris Pratt|Zoe Saldana|Dave Bautista|Vin Dies...
# Insurgent                Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                   director  runtime  \
# original_title
# Jurassic World             Colin Trevorrow      124
# Mad Max: Fury Road           George Miller      120
# Interstellar             Christopher Nolan      169
# Guardians of the Galaxy         James Gunn      121
# Insurgent                 Robert Schwentke      119
#
#                                                             genres  \
# original_title
# Jurassic World           Action|Adventure|Science Fiction|Thriller
# Mad Max: Fury Road       Action|Adventure|Science Fiction|Thriller
# Interstellar                       Adventure|Drama|Science Fiction
# Guardians of the Galaxy           Action|Science Fiction|Adventure
# Insurgent                       Adventure|Science Fiction|Thriller
#
#                                                       production_companies  \
# original_title
# Jurassic World           Universal Studios|Amblin Entertainment|Legenda...
# Mad Max: Fury Road       Village Roadshow Pictures|Kennedy Miller Produ...
# Interstellar             Paramount Pictures|Legendary Pictures|Warner B...
# Guardians of the Galaxy  Marvel Studios|Moving Picture Company (MPC)|Bu...
# Insurgent                Summit Entertainment|Mandeville Films|Red Wago...
#
#                         release_date  vote_count  vote_average  release_year  \
# original_title
# Jurassic World              6/9/2015        5562           6.5          2015
# Mad Max: Fury Road         5/13/2015        6185           7.1          2015
# Interstellar               11/5/2014        6498           8.0          2014
# Guardians of the Galaxy    7/30/2014        5612           7.9          2014
# Insurgent                  3/18/2015        2480           6.3          2015
#
#                           budget_adj   revenue_adj
# original_title
# Jurassic World           137999939.3  1.392446e+09
# Mad Max: Fury Road       137999939.3  3.481613e+08
# Interstellar             151980023.4  5.726906e+08
# Guardians of the Galaxy  156585478.6  7.122911e+08
# Insurgent                101199955.5  2.716190e+08

# %% [markdown]
# The above dataframe is sorted by most popular to least popular.
